# %% [markdown]
# # Librerie

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, LSTM, GRU
import holidays
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import scipy.stats as stats
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.stattools import acf
import warnings

# %% [markdown]
# # Importazione dataset e preprocessing

# %%
# Carico dati
restaurants = pd.read_csv('https://raw.githubusercontent.com/CoroTheBoss/DSL-project/main/restaurants.csv', sep=";")
restaurants['data'] = pd.to_datetime(restaurants['data'], format='%Y%m%d')
towns = pd.read_excel('Restaurant-Town.xlsx', header = None)
towns.columns = ['ristorante', 'città']
start_date = pd.Timestamp(2020, 5, 7)
restaurants = restaurants[restaurants['data'] >= start_date]
rest_towns = pd.merge(restaurants, towns, on='ristorante', how='inner')
rest_towns['day'] = rest_towns['data'].dt.strftime('%A')

def get_holiday(date):
    year = date.year
    it_holidays = holidays.Italy(years=year)
    return it_holidays.get(date)

rest_towns['festività'] = rest_towns['data'].apply(get_holiday)
df = rest_towns[rest_towns['ristorante']=='R000']
df = df.iloc[:-50]
df
# Out:
#            data  scontrini  lordototale ristorante       città       day  \
# 0    2020-05-07      181.0   12871.4754       R000  Montebello  Thursday
# 1    2020-05-08      239.0   15634.4867       R000  Montebello    Friday
# 2    2020-05-09      296.0   21602.9562       R000  Montebello  Saturday
# 3    2020-05-10      209.0   15185.5970       R000  Montebello    Sunday
# 4    2020-05-11      237.0   13828.3551       R000  Montebello    Monday
# ...         ...        ...          ...        ...         ...       ...
# 1065 2023-04-07     1051.0   48563.1832       R000  Montebello    Friday
# 1066 2023-04-08      993.0   52590.3875       R000  Montebello  Saturday
# 1067 2023-04-09      347.0   18194.5498       R000  Montebello    Sunday
# 1068 2023-04-10      687.0   34655.2017       R000  Montebello    Monday
# 1069 2023-04-11      638.0   33939.8444       R000  Montebello   Tuesday
#
#                    festività
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# ...                      ...
# 1065                    None
# 1066                    None
# 1067  Pasqua di Resurrezione
# 1068      Lunedì dell'Angelo
# 1069                    None
#
# [1070 rows x 7 columns]

# %% [markdown]
# # Plot serie temporale

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['data'],df['lordototale'],
         color='red', linewidth=0.5)
plt.title('Andamento temporale del lordototale')
plt.xlabel('Data')
plt.ylabel('Lordototale')
plt.grid(True)
# Salva il grafico ad alta qualità
#plt.savefig('Rist1_nocov.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Definizione, addestramento RNN

# %%
# Preparazione dei dati
data = df['lordototale'].values
data = data.reshape(-1, 1) 

# Divisione tra dati di addestramento e test
train_size = int(0.8 * len(data))
train_data = data[:train_size]
test_data = data[train_size:]

# Normalizzazione dei dati
scaler = StandardScaler()
train_data = scaler.fit_transform(train_data)
test_data = scaler.transform(test_data)

# Creazione delle finestre di dati
def create_sequences(data, window_size):
    sequences = []
    for i in range(len(data) - window_size):
        seq = data[i:i + window_size]
        label = data[i + window_size]
        sequences.append((seq, label))
    return sequences

window_size = 10
train_sequences = create_sequences(train_data, window_size)
test_sequences = create_sequences(test_data, window_size)

X_train = np.array([seq for seq, label in train_sequences])
y_train = np.array([label for seq, label in train_sequences])
X_test = np.array([seq for seq, label in test_sequences])
y_test = np.array([label for seq, label in test_sequences])

# Creazione del modello RNN
model = Sequential([
    SimpleRNN(32, activation='relu', input_shape=(window_size, 1)),
    Dense(1)
])

# Compilazione del modello con MSE
model.compile(optimizer='adam', loss='mean_squared_error')

# Definizione dell'early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Addestramento del modello con early stopping
history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 53/53 [==============================] - 1s 4ms/step - loss: 0.7820 - val_loss: 1.3960
# Epoch 2/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.4545 - val_loss: 0.9957
# Epoch 3/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.3590 - val_loss: 0.6495
# Epoch 4/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3164 - val_loss: 0.6843
# Epoch 5/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.3050 - val_loss: 0.5072
# Epoch 6/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2764 - val_loss: 0.6337
# Epoch 7/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2692 - val_loss: 0.6924
# Epoch 8/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2550 - val_loss: 0.5633
# Epoch 9/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2583 - val_loss: 0.7706
# Epoch 10/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2390 - val_loss: 0.6949
# Epoch 11/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2412 - val_loss: 0.6151
# Epoch 12/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2258 - val_loss: 0.5668
# Epoch 13/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2287 - val_loss: 0.5227
# Epoch 14/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2218 - val_loss: 0.6016
# Epoch 15/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2226 - val_loss: 0.6110

# %% [markdown]
# # Grafico MSE

# %%
# Plot della curva di perdita (MSE)
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error')
# Salva il grafico ad alta qualità
#plt.savefig('loss.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Calcolo metriche

# %%
# Ignora tutti i messaggi di avviso (warning)
warnings.filterwarnings("ignore")

predictions = model.predict(X_test)
predictions_denorm = scaler.inverse_transform(predictions)
y_test_denorm = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calcola l'errore assoluto percentuale medio (MAPE)
def calculate_mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Calcola l'errore assoluto medio (MAE)
mae = mean_absolute_error(y_test_denorm, predictions_denorm)

# Calcola l'errore quadratico medio (RMSE)
rmse = np.sqrt(mean_squared_error(y_test_denorm, predictions_denorm))

# Calcola l'errore percentuale medio (MPE)
mpe = np.mean((y_test_denorm - predictions_denorm) / y_test_denorm) * 100

# Calcola l'errore percentuale assoluto medio (MAPE)
mape = calculate_mape(y_test_denorm, predictions_denorm)

# Calcola l'autocorrelazione di previsioni
acf1 = acf(y_test_denorm - predictions_denorm, nlags=1)[1]

# Creazione di un DataFrame per mostrare tutte le metriche in maniera ordinata
metrics_df = pd.DataFrame({
    'RMSE': [rmse],
    'MAE': [mae],
    'MPE': [mpe],
    'MAPE': [mape],
    'ACF1': [acf1]
})

print(metrics_df)
# Out:
# 7/7 [==============================] - 0s 831us/step
#           RMSE          MAE       MPE       MAPE      ACF1
# 0  8666.088924  5392.106938 -1.860888  11.043148 -0.027969

# %% [markdown]
# # Test normalitá redisdui

# %%
# Calcolo gli errori residui
residues = (predictions_denorm - y_test_denorm).flatten()

# Calcolo la media e la varianza dei residui
residues_mean = np.mean(residues)
residues_var = np.var(residues)

print("Media dei Residui:", residues_mean)
print("Varianza dei Residui:", residues_var)

# Creo una griglia di subplots
plt.figure(figsize=(12, 6))

# Subplot 1: Grafico dei residui
plt.subplot(1, 2, 1)
plt.plot(residues)
plt.title('Residues')
plt.xlabel('Time')
plt.ylabel('Residues')

# Subplot 2: Grafico Q-Q
plt.subplot(1, 2, 2)
stats.probplot(residues, plot=plt)
plt.title('Q-Q Plot of Residues')

plt.tight_layout()
plt.show()
# Out:
# Media dei Residui: -362.0987260876218
# Varianza dei Residui: 74969981.74273725

# %% [markdown]
# # Plot previsioni

# %%
# Plot previsioni contro valori attesi
plt.figure(figsize=(12, 6))
plt.plot(y_test_denorm, label='Valori attesi')
plt.plot(predictions_denorm, label='Previsioni')
plt.xlabel('Tempo')
plt.ylabel('Valore')
plt.title('Confronto tra previsioni e valori attesi')
plt.legend()
# Salva il grafico ad alta qualità
#plt.savefig('RNN_previsioni.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # PREVISIONI FUTURE 6 RISTORANTI

# %%
# Lista dei ristoranti da R000 a R005
ristoranti_da_addestrare = ['R000', 'R001', 'R002', 'R003', 'R004', 'R005']

# Creazione di un dizionario per memorizzare i modelli addestrati
modelli_addestrati = {}

# Itero sui ristoranti da addestrare
for ristorante in ristoranti_da_addestrare:
    # Filtro i dati per il ristorante corrente
    df_ristorante = rest_towns[rest_towns['ristorante'] == ristorante]
    df_ristorante = df_ristorante.iloc[:-50]
    
    # Preparazione dei dati
    data_ristorante = df_ristorante['lordototale'].values
    data_ristorante = data_ristorante.reshape(-1, 1)
    
    # Divisione tra dati di addestramento e test
    train_size_ristorante = int(0.8 * len(data_ristorante))
    train_data_ristorante = data_ristorante[:train_size_ristorante]
    test_data_ristorante = data_ristorante[train_size_ristorante:]
    
    # Normalizzazione dei dati
    scaler_ristorante = StandardScaler()
    train_data_ristorante = scaler_ristorante.fit_transform(train_data_ristorante)
    test_data_ristorante = scaler_ristorante.transform(test_data_ristorante)
    
    # Creazione delle finestre di dati
    train_sequences_ristorante = create_sequences(train_data_ristorante, window_size)
    test_sequences_ristorante = create_sequences(test_data_ristorante, window_size)
    
    X_train_ristorante = np.array([seq for seq, label in train_sequences_ristorante])
    y_train_ristorante = np.array([label for seq, label in train_sequences_ristorante])
    X_test_ristorante = np.array([seq for seq, label in test_sequences_ristorante])
    y_test_ristorante = np.array([label for seq, label in test_sequences_ristorante])
    
    # Creazione del modello RNN
    model_ristorante = Sequential([
        SimpleRNN(32, activation='relu', input_shape=(window_size, 1)),
        Dense(1)
    ])
    
    # Compilazione del modello con MSE
    model_ristorante.compile(optimizer='adam', loss='mean_squared_error')
    
    # Definizione dell'early stopping
    early_stopping_ristorante = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    
    # Addestramento del modello con early stopping
    history_ristorante = model_ristorante.fit(X_train_ristorante, y_train_ristorante, epochs=100, batch_size=16, validation_data=(X_test_ristorante, y_test_ristorante), callbacks=[early_stopping_ristorante])
    
    # Memorizzazione il modello addestrato nel dizionario
    modelli_addestrati[ristorante] = (model_ristorante, scaler_ristorante)
# Out:
# Epoch 1/100
# 53/53 [==============================] - 1s 3ms/step - loss: 0.7667 - val_loss: 3.4859
# Epoch 2/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.5483 - val_loss: 2.3612
# Epoch 3/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.4157 - val_loss: 1.4421
# Epoch 4/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.3397 - val_loss: 1.0990
# Epoch 5/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.3201 - val_loss: 0.8506
# Epoch 6/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.3081 - val_loss: 0.9490
# Epoch 7/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2989 - val_loss: 0.9561
# Epoch 8/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2982 - val_loss: 0.8267
# Epoch 9/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2968 - val_loss: 0.7397
# Epoch 10/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2931 - val_loss: 0.8423
# Epoch 11/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2930 - val_loss: 0.7956
# Epoch 12/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2943 - val_loss: 0.8171
# Epoch 13/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2853 - val_loss: 0.7586
# Epoch 14/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2882 - val_loss: 0.8158
# Epoch 15/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2850 - val_loss: 0.8719
# Epoch 16/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2791 - val_loss: 0.8570
# Epoch 17/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2753 - val_loss: 0.8591
# Epoch 18/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2698 - val_loss: 0.8045
# Epoch 19/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2698 - val_loss: 0.7601
# Epoch 1/100
# 53/53 [==============================] - 1s 3ms/step - loss: 0.8555 - val_loss: 1.2169
# Epoch 2/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.4654 - val_loss: 0.9243
# Epoch 3/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.3462 - val_loss: 0.7087
# Epoch 4/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.3000 - val_loss: 0.6543
# Epoch 5/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2806 - val_loss: 0.5420
# Epoch 6/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2672 - val_loss: 0.6627
# Epoch 7/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2563 - val_loss: 0.5811
# Epoch 8/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2487 - val_loss: 0.6432
# Epoch 9/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2370 - val_loss: 0.5647
# Epoch 10/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2360 - val_loss: 0.5539
# Epoch 11/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2269 - val_loss: 0.6212
# Epoch 12/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2253 - val_loss: 0.6462
# Epoch 13/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2234 - val_loss: 0.6941
# Epoch 14/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2172 - val_loss: 0.5790
# Epoch 15/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2225 - val_loss: 0.6453
# Epoch 1/100
# 53/53 [==============================] - 1s 3ms/step - loss: 0.8271 - val_loss: 1.1142
# Epoch 2/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6559 - val_loss: 0.8400
# Epoch 3/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.5548 - val_loss: 0.9896
# Epoch 4/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.4609 - val_loss: 0.9505
# Epoch 5/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.4063 - val_loss: 0.5444
# Epoch 6/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.3610 - val_loss: 0.4651
# Epoch 7/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.3381 - val_loss: 0.4696
# Epoch 8/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.3159 - val_loss: 0.4696
# Epoch 9/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.3095 - val_loss: 0.5012
# Epoch 10/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2971 - val_loss: 0.5412
# Epoch 11/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2851 - val_loss: 0.5493
# Epoch 12/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2826 - val_loss: 0.5290
# Epoch 13/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2718 - val_loss: 0.5004
# Epoch 14/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2733 - val_loss: 0.6087
# Epoch 15/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2727 - val_loss: 0.4911
# Epoch 16/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2665 - val_loss: 0.5020
# Epoch 1/100
# 53/53 [==============================] - 1s 3ms/step - loss: 0.5932 - val_loss: 0.8847
# Epoch 2/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.3859 - val_loss: 0.8567
# Epoch 3/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.3610 - val_loss: 0.7284
# Epoch 4/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.3408 - val_loss: 0.6606
# Epoch 5/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.3285 - val_loss: 0.6509
# Epoch 6/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3140 - val_loss: 0.6592
# Epoch 7/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2997 - val_loss: 0.6319
# Epoch 8/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2920 - val_loss: 0.5592
# Epoch 9/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2823 - val_loss: 0.5485
# Epoch 10/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2746 - val_loss: 0.5532
# Epoch 11/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2717 - val_loss: 0.5760
# Epoch 12/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2707 - val_loss: 0.5391
# Epoch 13/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2630 - val_loss: 0.5849
# Epoch 14/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2618 - val_loss: 0.5342
# Epoch 15/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2544 - val_loss: 0.7350
# Epoch 16/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2603 - val_loss: 0.5738
# Epoch 17/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2516 - val_loss: 0.5186
# Epoch 18/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2472 - val_loss: 0.5141
# Epoch 19/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2470 - val_loss: 0.5799
# Epoch 20/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2385 - val_loss: 0.5246
# Epoch 21/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2382 - val_loss: 0.5773
# Epoch 22/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2380 - val_loss: 0.5836
# Epoch 23/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2390 - val_loss: 0.5740
# Epoch 24/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2295 - val_loss: 0.5210
# Epoch 25/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2267 - val_loss: 0.6883
# Epoch 26/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2231 - val_loss: 0.5239
# Epoch 27/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2235 - val_loss: 0.5248
# Epoch 28/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2236 - val_loss: 0.6564
# Epoch 1/100
# 53/53 [==============================] - 1s 3ms/step - loss: 0.5650 - val_loss: 1.1909
# Epoch 2/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.3517 - val_loss: 0.5792
# Epoch 3/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2386 - val_loss: 0.5180
# Epoch 4/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2228 - val_loss: 0.5662
# Epoch 5/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2039 - val_loss: 0.4992
# Epoch 6/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1947 - val_loss: 0.5561
# Epoch 7/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1891 - val_loss: 0.5017
# Epoch 8/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1824 - val_loss: 0.4773
# Epoch 9/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1826 - val_loss: 0.5196
# Epoch 10/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1734 - val_loss: 0.5216
# Epoch 11/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1714 - val_loss: 0.4798
# Epoch 12/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1696 - val_loss: 0.4717
# Epoch 13/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1650 - val_loss: 0.4698
# Epoch 14/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1662 - val_loss: 0.4784
# Epoch 15/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1617 - val_loss: 0.4737
# Epoch 16/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1645 - val_loss: 0.5014
# Epoch 17/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1601 - val_loss: 0.4775
# Epoch 18/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1572 - val_loss: 0.4698
# Epoch 19/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1611 - val_loss: 0.4814
# Epoch 20/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1561 - val_loss: 0.4976
# Epoch 21/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1535 - val_loss: 0.4751
# Epoch 22/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1538 - val_loss: 0.4836
# Epoch 23/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1526 - val_loss: 0.4781
# Epoch 24/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1504 - val_loss: 0.4696
# Epoch 25/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1488 - val_loss: 0.4709
# Epoch 26/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1450 - val_loss: 0.4872
# Epoch 27/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1452 - val_loss: 0.4928
# Epoch 28/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1469 - val_loss: 0.4872
# Epoch 29/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1440 - val_loss: 0.4776
# Epoch 30/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1396 - val_loss: 0.4881
# Epoch 31/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1412 - val_loss: 0.4938
# Epoch 32/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1429 - val_loss: 0.4774
# Epoch 33/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1437 - val_loss: 0.4880
# Epoch 34/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1382 - val_loss: 0.5042
# Epoch 1/100
# 53/53 [==============================] - 1s 3ms/step - loss: 0.7026 - val_loss: 1.3584
# Epoch 2/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.3964 - val_loss: 0.7438
# Epoch 3/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2973 - val_loss: 0.6707
# Epoch 4/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2683 - val_loss: 0.6430
# Epoch 5/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2588 - val_loss: 0.6673
# Epoch 6/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2491 - val_loss: 0.5408
# Epoch 7/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2429 - val_loss: 0.5369
# Epoch 8/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2372 - val_loss: 0.6291
# Epoch 9/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2403 - val_loss: 0.5723
# Epoch 10/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2314 - val_loss: 0.6497
# Epoch 11/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2307 - val_loss: 0.6083
# Epoch 12/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2327 - val_loss: 0.5417
# Epoch 13/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2237 - val_loss: 0.6078
# Epoch 14/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2214 - val_loss: 0.5356
# Epoch 15/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2186 - val_loss: 0.5784
# Epoch 16/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2199 - val_loss: 0.6544
# Epoch 17/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2177 - val_loss: 0.6483
# Epoch 18/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2180 - val_loss: 0.6471
# Epoch 19/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2130 - val_loss: 0.5455
# Epoch 20/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2119 - val_loss: 0.6323
# Epoch 21/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2058 - val_loss: 0.7135
# Epoch 22/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2137 - val_loss: 0.5811
# Epoch 23/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2077 - val_loss: 0.6106
# Epoch 24/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2039 - val_loss: 0.5226
# Epoch 25/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2020 - val_loss: 0.5638
# Epoch 26/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2042 - val_loss: 0.6150
# Epoch 27/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1962 - val_loss: 0.5839
# Epoch 28/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1938 - val_loss: 0.5826
# Epoch 29/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1923 - val_loss: 0.6755
# Epoch 30/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1956 - val_loss: 0.5690
# Epoch 31/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1890 - val_loss: 0.5566
# Epoch 32/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1913 - val_loss: 0.6896
# Epoch 33/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1915 - val_loss: 0.5894
# Epoch 34/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1939 - val_loss: 0.5914

# %%
def generate_future_predictions(model, scaler, initial_sequence, future_steps):
    predictions = []

    # Copio la sequenza iniziale
    current_sequence = initial_sequence.copy()

    for _ in range(future_steps):
        # Effettuo una previsione per il passo successivo
        next_step = model.predict(current_sequence.reshape(1, -1, 1))
        
        # Aggiungo la previsione alla lista delle previsioni
        predictions.append(next_step[0, 0])
        
        # Aggiorno la sequenza corrente con la nuova previsione
        current_sequence = np.roll(current_sequence, shift=-1)
        current_sequence[-1] = next_step[0, 0]
        
    # Reverto la normalizzazione alle previsioni
    predictions = scaler.inverse_transform(np.array(predictions).reshape(-1, 1))
    
    return predictions

# Numero di previsioni future da generare
future_steps = 20

# Creo una figura per il plot
plt.figure(figsize=(12, 6))
plt.style.use('seaborn-darkgrid')

# Colori per le linee dei ristoranti
colors = ['b', 'g', 'r', 'c', 'm', 'y']

for i, ristorante in enumerate(ristoranti_da_addestrare):
    # Ottengo il modello e lo scaler dal dizionario
    model_ristorante, scaler_ristorante = modelli_addestrati[ristorante]
    
    # Prendo l'ultima sequenza di dati dal set di test
    last_sequence = X_test_ristorante[-1]
    
    # Genero le previsioni future per il ristorante corrente
    future_predictions = generate_future_predictions(model_ristorante, scaler_ristorante, last_sequence, future_steps)
    
    # Creo un array di passi temporali per il plot
    time_steps = np.arange(1, future_steps + 1)
    
    # Plotto le previsioni future con stile
    plt.plot(time_steps, future_predictions, label=f'Ristorante {ristorante}', color=colors[i], linewidth=2)

# Aggiungo etichette e legenda al plot
plt.xlabel('Passi Temporali Futuri')
plt.ylabel('Valore Predetto')
plt.title('Previsioni Future per i Ristoranti')
plt.legend()

# Mostro il plot
plt.tight_layout()
# Salvo il grafico ad alta qualità
#plt.savefig('future.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step

# %%
# Crezione un dizionario per memorizzare le somme delle previsioni per ciascun ristorante
total_revenues_by_restaurant = {}

for ristorante in ristoranti_da_addestrare:
    # Ottengo il modello e lo scaler dal dizionario
    model_ristorante, scaler_ristorante = modelli_addestrati[ristorante]
    
    # Prendo l'ultima sequenza di dati dal set di test
    last_sequence = X_test_ristorante[-1]
    
    # Genero le previsioni future per il ristorante corrente
    future_predictions = generate_future_predictions(model_ristorante, scaler_ristorante, last_sequence, future_steps)
    
    # Calcolo la somma delle previsioni per il ristorante corrente
    total_revenue = np.sum(future_predictions)
    
    # Memorizzo la somma delle previsioni nel dizionario
    total_revenues_by_restaurant[ristorante] = total_revenue

# Stampo le stime dell'incasso totale per ciascun ristorante
for ristorante, revenue in total_revenues_by_restaurant.items():
    print(f"Stima dell'incasso totale per Ristorante {ristorante} nei prossimi 30 giorni: {revenue:.2f} Euro")
# Out:
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# Stima dell'incasso totale per Ristorante R000 nei prossimi 30 giorni: 638076.75 Euro
# Stima dell'incasso totale per Ristorante R001 nei prossimi 30 giorni: 999682.81 Euro
# Stima dell'incasso totale per Ristorante R002 nei prossimi 30 giorni: 970180.50 Euro
# Stima dell'incasso totale per Ristorante R003 nei prossimi 30 giorni: 473346.25 Euro
# Stima dell'incasso totale per Ristorante R004 nei prossimi 30 giorni: 837878.44 Euro
# Stima dell'incasso totale per Ristorante R005 nei prossimi 30 giorni: 809507.50 Euro
