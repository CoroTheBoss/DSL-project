# %% [markdown]
# # Librerie

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, LSTM, GRU
import holidays
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import scipy.stats as stats
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.stattools import acf
import warnings

# %% [markdown]
# # Importazione dataset e preprocessing

# %%
# Carico dati
restaurants = pd.read_csv('https://raw.githubusercontent.com/CoroTheBoss/DSL-project/main/restaurants.csv', sep=";")
restaurants['data'] = pd.to_datetime(restaurants['data'], format='%Y%m%d')
towns = pd.read_csv('https://raw.githubusercontent.com/CoroTheBoss/DSL-project/main/Restaurant-Town.csv', header = None)
towns.columns = ['ristorante', 'città']
start_date = pd.Timestamp(2020, 5, 7)
restaurants = restaurants[restaurants['data'] >= start_date]
rest_towns = pd.merge(restaurants, towns, on='ristorante', how='inner')
rest_towns['day'] = rest_towns['data'].dt.strftime('%A')

def get_holiday(date):
    year = date.year
    it_holidays = holidays.Italy(years=year)
    return it_holidays.get(date)

rest_towns['festività'] = rest_towns['data'].apply(get_holiday)
# Out:
#            data  scontrini  lordototale ristorante     città       day  \
# 5600 2020-05-07      202.0   14060.5437       R002  Piacenza  Thursday
# 5601 2020-05-08      254.0   18705.5960       R002  Piacenza    Friday
# 5602 2020-05-09      246.0   20172.3242       R002  Piacenza  Saturday
# 5603 2020-05-10      214.0   17053.5960       R002  Piacenza    Sunday
# 5604 2020-05-11      212.0   14738.3180       R002  Piacenza    Monday
# ...         ...        ...          ...        ...       ...       ...
# 6665 2023-04-07     1073.0   61274.3320       R002  Piacenza    Friday
# 6666 2023-04-08     1030.0   59125.7408       R002  Piacenza  Saturday
# 6667 2023-04-09      579.0   33832.5057       R002  Piacenza    Sunday
# 6668 2023-04-10      861.0   56245.1484       R002  Piacenza    Monday
# 6669 2023-04-11      753.0   41941.8846       R002  Piacenza   Tuesday
#
#                    festività
# 5600                    None
# 5601                    None
# 5602                    None
# 5603                    None
# 5604                    None
# ...                      ...
# 6665                    None
# 6666                    None
# 6667  Pasqua di Resurrezione
# 6668      Lunedì dell'Angelo
# 6669                    None
#
# [1070 rows x 7 columns]

# %%
df = rest_towns[rest_towns['ristorante']=='R000']
df = df.iloc[:-50]
df
# Out:
#            data  scontrini  lordototale ristorante       città       day  \
# 0    2020-05-07      181.0   12871.4754       R000  Montebello  Thursday
# 1    2020-05-08      239.0   15634.4867       R000  Montebello    Friday
# 2    2020-05-09      296.0   21602.9562       R000  Montebello  Saturday
# 3    2020-05-10      209.0   15185.5970       R000  Montebello    Sunday
# 4    2020-05-11      237.0   13828.3551       R000  Montebello    Monday
# ...         ...        ...          ...        ...         ...       ...
# 1065 2023-04-07     1051.0   48563.1832       R000  Montebello    Friday
# 1066 2023-04-08      993.0   52590.3875       R000  Montebello  Saturday
# 1067 2023-04-09      347.0   18194.5498       R000  Montebello    Sunday
# 1068 2023-04-10      687.0   34655.2017       R000  Montebello    Monday
# 1069 2023-04-11      638.0   33939.8444       R000  Montebello   Tuesday
#
#                    festività
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# ...                      ...
# 1065                    None
# 1066                    None
# 1067  Pasqua di Resurrezione
# 1068      Lunedì dell'Angelo
# 1069                    None
#
# [1070 rows x 7 columns]

# %% [markdown]
# # Plot serie temporale

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['data'],df['lordototale'],
         color='red', linewidth=0.5)
plt.title('Andamento temporale del lordototale')
plt.xlabel('Data')
plt.ylabel('Lordototale')
plt.grid(True)
# Salva il grafico ad alta qualità
#plt.savefig('Rist1_nocov.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Definizione, addestramento RNN

# %%
# Preparazione dei dati
data = df['lordototale'].values
data = data.reshape(-1, 1) 

# Divisione tra dati di addestramento e test
train_size = int(0.8 * len(data))
train_data = data[:train_size]
test_data = data[train_size:]

# Normalizzazione dei dati
scaler = StandardScaler()
train_data = scaler.fit_transform(train_data)
test_data = scaler.transform(test_data)

# Creazione delle finestre di dati
def create_sequences(data, window_size):
    sequences = []
    for i in range(len(data) - window_size):
        seq = data[i:i + window_size]
        label = data[i + window_size]
        sequences.append((seq, label))
    return sequences

window_size = 10
train_sequences = create_sequences(train_data, window_size)
test_sequences = create_sequences(test_data, window_size)

X_train = np.array([seq for seq, label in train_sequences])
y_train = np.array([label for seq, label in train_sequences])
X_test = np.array([seq for seq, label in test_sequences])
y_test = np.array([label for seq, label in test_sequences])

# Creazione del modello RNN
model = Sequential([
    SimpleRNN(32, activation='relu', input_shape=(window_size, 1)),
    Dense(1)
])

# Compilazione del modello con MSE
model.compile(optimizer='adam', loss='mean_squared_error')

# Definizione dell'early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Addestramento del modello con early stopping
history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 53/53 [==============================] - 1s 3ms/step - loss: 0.6058 - val_loss: 1.1395
# Epoch 2/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3681 - val_loss: 0.7775
# Epoch 3/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3348 - val_loss: 0.6860
# Epoch 4/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3106 - val_loss: 0.8711
# Epoch 5/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3005 - val_loss: 0.8434
# Epoch 6/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2987 - val_loss: 0.7381
# Epoch 7/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2956 - val_loss: 0.7125
# Epoch 8/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2850 - val_loss: 0.6607
# Epoch 9/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2907 - val_loss: 0.7341
# Epoch 10/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2799 - val_loss: 0.6916
# Epoch 11/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2824 - val_loss: 0.6570
# Epoch 12/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2856 - val_loss: 0.7580
# Epoch 13/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2775 - val_loss: 0.6972
# Epoch 14/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2795 - val_loss: 0.6668
# Epoch 15/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2697 - val_loss: 0.7493
# Epoch 16/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2690 - val_loss: 0.7268
# Epoch 17/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2671 - val_loss: 0.8118
# Epoch 18/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2667 - val_loss: 0.8149
# Epoch 19/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2608 - val_loss: 0.6506
# Epoch 20/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2655 - val_loss: 0.6576
# Epoch 21/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2735 - val_loss: 0.7608
# Epoch 22/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2576 - val_loss: 0.6890
# Epoch 23/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2630 - val_loss: 0.7471
# Epoch 24/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2571 - val_loss: 0.7473
# Epoch 25/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2527 - val_loss: 0.7228
# Epoch 26/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2533 - val_loss: 0.7356
# Epoch 27/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2611 - val_loss: 0.8684
# Epoch 28/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2465 - val_loss: 0.7960
# Epoch 29/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2468 - val_loss: 0.7655

# %% [markdown]
# # Grafico MSE

# %%
# Plot della curva di perdita (MSE)
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error')
# Salva il grafico ad alta qualità
#plt.savefig('loss.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Calcolo metriche

# %%
# Ignora tutti i messaggi di avviso (warning)
warnings.filterwarnings("ignore")

predictions = model.predict(X_test)
predictions_denorm = scaler.inverse_transform(predictions)
y_test_denorm = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calcola l'errore assoluto percentuale medio (MAPE)
def calculate_mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Calcola l'errore assoluto medio (MAE)
mae = mean_absolute_error(y_test_denorm, predictions_denorm)

# Calcola l'errore quadratico medio (RMSE)
rmse = np.sqrt(mean_squared_error(y_test_denorm, predictions_denorm))

# Calcola l'errore percentuale medio (MPE)
mpe = np.mean((y_test_denorm - predictions_denorm) / y_test_denorm) * 100

# Calcola l'errore percentuale assoluto medio (MAPE)
mape = calculate_mape(y_test_denorm, predictions_denorm)

# Calcola l'autocorrelazione di previsioni
acf1 = acf(y_test_denorm - predictions_denorm, nlags=1)[1]

# Creazione di un DataFrame per mostrare tutte le metriche in maniera ordinata
metrics_df = pd.DataFrame({
    'RMSE': [rmse],
    'MAE': [mae],
    'MPE': [mpe],
    'MAPE': [mape],
    'ACF1': [acf1]
})

print(metrics_df)
# Out:
# 7/7 [==============================] - 0s 1ms/step
#           RMSE          MAE       MPE       MAPE      ACF1
# 0  6446.586123  4479.182488 -2.269511  14.216955  0.059877

# %% [markdown]
# # Test normalitá redisdui

# %%
# Calcolo gli errori residui
residues = (predictions_denorm - y_test_denorm).flatten()

# Calcolo la media e la varianza dei residui
residues_mean = np.mean(residues)
residues_var = np.var(residues)

print("Media dei Residui:", residues_mean)
print("Varianza dei Residui:", residues_var)

# Creo una griglia di subplots
plt.figure(figsize=(12, 6))

# Subplot 1: Grafico dei residui
plt.subplot(1, 2, 1)
plt.plot(residues)
plt.title('Residues')
plt.xlabel('Time')
plt.ylabel('Residues')

# Subplot 2: Grafico Q-Q
plt.subplot(1, 2, 2)
stats.probplot(residues, plot=plt)
plt.title('Q-Q Plot of Residues')

plt.tight_layout()
plt.show()
# Out:
# Media dei Residui: -584.1317137408087
# Varianza dei Residui: 41217262.78287268

# %% [markdown]
# # Plot previsioni

# %%
# Plot previsioni contro valori attesi
plt.figure(figsize=(12, 6))
plt.plot(y_test_denorm, label='Valori attesi')
plt.plot(predictions_denorm, label='Previsioni')
plt.xlabel('Tempo')
plt.ylabel('Valore')
plt.title('Confronto tra previsioni e valori attesi')
plt.legend()
# Salva il grafico ad alta qualità
#plt.savefig('RNN_previsioni.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # PREVISIONI FUTURE 6 RISTORANTI

# %%
# Lista dei ristoranti da R000 a R005
ristoranti_da_addestrare = ['R000', 'R001', 'R002', 'R003', 'R004', 'R005']

# Creazione di un dizionario per memorizzare i modelli addestrati
modelli_addestrati = {}

# Itero sui ristoranti da addestrare
for ristorante in ristoranti_da_addestrare:
    # Filtro i dati per il ristorante corrente
    df_ristorante = rest_towns[rest_towns['ristorante'] == ristorante]
    df_ristorante = df_ristorante.iloc[:-50]
    
    # Preparazione dei dati
    data_ristorante = df_ristorante['lordototale'].values
    data_ristorante = data_ristorante.reshape(-1, 1)
    
    # Divisione tra dati di addestramento e test
    train_size_ristorante = int(0.8 * len(data_ristorante))
    train_data_ristorante = data_ristorante[:train_size_ristorante]
    test_data_ristorante = data_ristorante[train_size_ristorante:]
    
    # Normalizzazione dei dati
    scaler_ristorante = StandardScaler()
    train_data_ristorante = scaler_ristorante.fit_transform(train_data_ristorante)
    test_data_ristorante = scaler_ristorante.transform(test_data_ristorante)
    
    # Creazione delle finestre di dati
    train_sequences_ristorante = create_sequences(train_data_ristorante, window_size)
    test_sequences_ristorante = create_sequences(test_data_ristorante, window_size)
    
    X_train_ristorante = np.array([seq for seq, label in train_sequences_ristorante])
    y_train_ristorante = np.array([label for seq, label in train_sequences_ristorante])
    X_test_ristorante = np.array([seq for seq, label in test_sequences_ristorante])
    y_test_ristorante = np.array([label for seq, label in test_sequences_ristorante])
    
    # Creazione del modello RNN
    model_ristorante = Sequential([
        SimpleRNN(32, activation='relu', input_shape=(window_size, 1)),
        Dense(1)
    ])
    
    # Compilazione del modello con MSE
    model_ristorante.compile(optimizer='adam', loss='mean_squared_error')
    
    # Definizione dell'early stopping
    early_stopping_ristorante = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    
    # Addestramento del modello con early stopping
    history_ristorante = model_ristorante.fit(X_train_ristorante, y_train_ristorante, epochs=100, batch_size=16, validation_data=(X_test_ristorante, y_test_ristorante), callbacks=[early_stopping_ristorante])
    
    # Memorizzazione il modello addestrato nel dizionario
    modelli_addestrati[ristorante] = (model_ristorante, scaler_ristorante)
# Out:
# Epoch 1/100
# 53/53 [==============================] - 1s 3ms/step - loss: 0.5740 - val_loss: 0.8698
# Epoch 2/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3579 - val_loss: 0.7202
# Epoch 3/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3284 - val_loss: 0.7944
# Epoch 4/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.3071 - val_loss: 0.7217
# Epoch 5/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3063 - val_loss: 0.6541
# Epoch 6/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2923 - val_loss: 0.6761
# Epoch 7/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2918 - val_loss: 0.7363
# Epoch 8/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2915 - val_loss: 0.6816
# Epoch 9/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2876 - val_loss: 0.6279
# Epoch 10/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2808 - val_loss: 0.7100
# Epoch 11/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2764 - val_loss: 0.6746
# Epoch 12/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2808 - val_loss: 0.6141
# Epoch 13/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2692 - val_loss: 0.6455
# Epoch 14/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2652 - val_loss: 0.7256
# Epoch 15/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2656 - val_loss: 0.6534
# Epoch 16/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2615 - val_loss: 0.6522
# Epoch 17/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2657 - val_loss: 0.6240
# Epoch 18/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2614 - val_loss: 0.6176
# Epoch 19/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2654 - val_loss: 0.6312
# Epoch 20/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2533 - val_loss: 0.6421
# Epoch 21/100
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2507 - val_loss: 0.6602
# Epoch 22/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2512 - val_loss: 0.6397
# Epoch 1/100
# 53/53 [==============================] - 1s 4ms/step - loss: 0.7557 - val_loss: 1.8881
# Epoch 2/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.5234 - val_loss: 1.3651
# Epoch 3/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3786 - val_loss: 0.8752
# Epoch 4/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2992 - val_loss: 0.7469
# Epoch 5/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2663 - val_loss: 0.6159
# Epoch 6/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2456 - val_loss: 0.6421
# Epoch 7/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2297 - val_loss: 0.7938
# Epoch 8/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2242 - val_loss: 0.6733
# Epoch 9/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2214 - val_loss: 0.6917
# Epoch 10/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2136 - val_loss: 0.7337
# Epoch 11/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2104 - val_loss: 0.6741
# Epoch 12/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2042 - val_loss: 0.7495
# Epoch 13/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2070 - val_loss: 0.5761
# Epoch 14/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1988 - val_loss: 0.7284
# Epoch 15/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1959 - val_loss: 0.6831
# Epoch 16/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1937 - val_loss: 0.7123
# Epoch 17/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1950 - val_loss: 0.6143
# Epoch 18/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1932 - val_loss: 0.6051
# Epoch 19/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1830 - val_loss: 0.8154
# Epoch 20/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1847 - val_loss: 0.6387
# Epoch 21/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1842 - val_loss: 0.7584
# Epoch 22/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1823 - val_loss: 0.6933
# Epoch 23/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1816 - val_loss: 0.7769
# Epoch 1/100
# 53/53 [==============================] - 1s 4ms/step - loss: 0.8565 - val_loss: 1.4013
# Epoch 2/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.5443 - val_loss: 0.7088
# Epoch 3/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.4075 - val_loss: 0.5079
# Epoch 4/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3768 - val_loss: 0.5202
# Epoch 5/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3380 - val_loss: 0.5330
# Epoch 6/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3179 - val_loss: 0.4869
# Epoch 7/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3026 - val_loss: 0.5121
# Epoch 8/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2946 - val_loss: 0.4588
# Epoch 9/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2854 - val_loss: 0.5376
# Epoch 10/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2799 - val_loss: 0.5455
# Epoch 11/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2761 - val_loss: 0.4751
# Epoch 12/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2723 - val_loss: 0.4529
# Epoch 13/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2718 - val_loss: 0.4614
# Epoch 14/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2672 - val_loss: 0.4560
# Epoch 15/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2657 - val_loss: 0.5216
# Epoch 16/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2563 - val_loss: 0.4451
# Epoch 17/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2475 - val_loss: 0.4817
# Epoch 18/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2470 - val_loss: 0.4823
# Epoch 19/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2411 - val_loss: 0.4311
# Epoch 20/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2397 - val_loss: 0.4502
# Epoch 21/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2414 - val_loss: 0.4344
# Epoch 22/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2361 - val_loss: 0.5066
# Epoch 23/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2376 - val_loss: 0.4465
# Epoch 24/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2303 - val_loss: 0.4491
# Epoch 25/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2336 - val_loss: 0.4369
# Epoch 26/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2285 - val_loss: 0.4426
# Epoch 27/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2280 - val_loss: 0.4853
# Epoch 28/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2197 - val_loss: 0.4491
# Epoch 29/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2178 - val_loss: 0.4379
# Epoch 1/100
# 53/53 [==============================] - 1s 4ms/step - loss: 0.6523 - val_loss: 1.0619
# Epoch 2/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.4096 - val_loss: 0.8292
# Epoch 3/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3785 - val_loss: 0.7191
# Epoch 4/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3640 - val_loss: 0.8713
# Epoch 5/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3506 - val_loss: 0.6483
# Epoch 6/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3357 - val_loss: 0.6263
# Epoch 7/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3321 - val_loss: 0.6287
# Epoch 8/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3065 - val_loss: 0.6252
# Epoch 9/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3022 - val_loss: 0.6016
# Epoch 10/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2864 - val_loss: 0.6940
# Epoch 11/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2777 - val_loss: 0.6127
# Epoch 12/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2729 - val_loss: 0.5868
# Epoch 13/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2744 - val_loss: 0.7060
# Epoch 14/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2682 - val_loss: 0.6143
# Epoch 15/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2686 - val_loss: 0.6986
# Epoch 16/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2591 - val_loss: 0.5952
# Epoch 17/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2530 - val_loss: 0.6673
# Epoch 18/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2510 - val_loss: 0.5923
# Epoch 19/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2494 - val_loss: 0.6009
# Epoch 20/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2430 - val_loss: 0.6011
# Epoch 21/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2492 - val_loss: 0.5898
# Epoch 22/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2390 - val_loss: 0.6871
# Epoch 1/100
# 53/53 [==============================] - 1s 4ms/step - loss: 0.6786 - val_loss: 1.5629
# Epoch 2/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2909 - val_loss: 0.4860
# Epoch 3/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2143 - val_loss: 0.4780
# Epoch 4/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1972 - val_loss: 0.4934
# Epoch 5/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1929 - val_loss: 0.4639
# Epoch 6/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1901 - val_loss: 0.4654
# Epoch 7/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1913 - val_loss: 0.4580
# Epoch 8/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1859 - val_loss: 0.4640
# Epoch 9/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1790 - val_loss: 0.4520
# Epoch 10/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1776 - val_loss: 0.4667
# Epoch 11/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1746 - val_loss: 0.5907
# Epoch 12/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1737 - val_loss: 0.4523
# Epoch 13/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1701 - val_loss: 0.5106
# Epoch 14/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1718 - val_loss: 0.4907
# Epoch 15/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1661 - val_loss: 0.4775
# Epoch 16/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1681 - val_loss: 0.4634
# Epoch 17/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1627 - val_loss: 0.4580
# Epoch 18/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1618 - val_loss: 0.4796
# Epoch 19/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1656 - val_loss: 0.4693
# Epoch 1/100
# 53/53 [==============================] - 1s 4ms/step - loss: 0.6950 - val_loss: 1.2035
# Epoch 2/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3879 - val_loss: 0.9659
# Epoch 3/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3158 - val_loss: 0.7487
# Epoch 4/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2907 - val_loss: 0.6491
# Epoch 5/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2765 - val_loss: 0.7051
# Epoch 6/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2661 - val_loss: 0.6453
# Epoch 7/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2607 - val_loss: 0.6998
# Epoch 8/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2478 - val_loss: 0.6146
# Epoch 9/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2466 - val_loss: 0.5484
# Epoch 10/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2351 - val_loss: 0.6633
# Epoch 11/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2324 - val_loss: 0.7576
# Epoch 12/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2349 - val_loss: 0.5556
# Epoch 13/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2267 - val_loss: 0.5645
# Epoch 14/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2231 - val_loss: 0.5465
# Epoch 15/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2227 - val_loss: 0.6366
# Epoch 16/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2169 - val_loss: 0.5935
# Epoch 17/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2122 - val_loss: 0.6242
# Epoch 18/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2187 - val_loss: 0.5568
# Epoch 19/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2095 - val_loss: 0.5464
# Epoch 20/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2113 - val_loss: 0.5505
# Epoch 21/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2074 - val_loss: 0.5590
# Epoch 22/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2031 - val_loss: 0.5320
# Epoch 23/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2026 - val_loss: 0.5373
# Epoch 24/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1997 - val_loss: 0.6680
# Epoch 25/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2023 - val_loss: 0.5593
# Epoch 26/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1947 - val_loss: 0.5354
# Epoch 27/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1949 - val_loss: 0.5907
# Epoch 28/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1910 - val_loss: 0.7195
# Epoch 29/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1927 - val_loss: 0.6078
# Epoch 30/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1889 - val_loss: 0.5296
# Epoch 31/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1863 - val_loss: 0.6515
# Epoch 32/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1825 - val_loss: 0.5642
# Epoch 33/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1840 - val_loss: 0.5514
# Epoch 34/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1807 - val_loss: 0.5373
# Epoch 35/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1808 - val_loss: 0.5398
# Epoch 36/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1770 - val_loss: 0.5576
# Epoch 37/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1777 - val_loss: 0.6776
# Epoch 38/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1731 - val_loss: 0.6939
# Epoch 39/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1685 - val_loss: 0.5636
# Epoch 40/100
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1692 - val_loss: 0.6717

# %%
def generate_future_predictions(model, scaler, initial_sequence, future_steps):
    predictions = []

    # Copio la sequenza iniziale
    current_sequence = initial_sequence.copy()

    for _ in range(future_steps):
        # Effettuo una previsione per il passo successivo
        next_step = model.predict(current_sequence.reshape(1, -1, 1))
        
        # Aggiungo la previsione alla lista delle previsioni
        predictions.append(next_step[0, 0])
        
        # Aggiorno la sequenza corrente con la nuova previsione
        current_sequence = np.roll(current_sequence, shift=-1)
        current_sequence[-1] = next_step[0, 0]
        
    # Reverto la normalizzazione alle previsioni
    predictions = scaler.inverse_transform(np.array(predictions).reshape(-1, 1))
    
    return predictions

# Numero di previsioni future da generare
future_steps = 20

# Creo una figura per il plot
plt.figure(figsize=(12, 6))
plt.style.use('seaborn-darkgrid')

# Colori per le linee dei ristoranti
colors = ['b', 'g', 'r', 'c', 'm', 'y']

for i, ristorante in enumerate(ristoranti_da_addestrare):
    # Ottengo il modello e lo scaler dal dizionario
    model_ristorante, scaler_ristorante = modelli_addestrati[ristorante]
    
    # Prendo l'ultima sequenza di dati dal set di test
    last_sequence = X_test_ristorante[-1]
    
    # Genero le previsioni future per il ristorante corrente
    future_predictions = generate_future_predictions(model_ristorante, scaler_ristorante, last_sequence, future_steps)
    
    # Creo un array di passi temporali per il plot
    time_steps = np.arange(1, future_steps + 1)
    
    # Plotto le previsioni future con stile
    plt.plot(time_steps, future_predictions, label=f'Ristorante {ristorante}', color=colors[i], linewidth=2)

# Aggiungo etichette e legenda al plot
plt.xlabel('Passi Temporali Futuri')
plt.ylabel('Valore Predetto')
plt.title('Previsioni Future per i Ristoranti')
plt.legend()

# Mostro il plot
plt.tight_layout()
# Salvo il grafico ad alta qualità
#plt.savefig('future.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step

# %%
# Crezione un dizionario per memorizzare le somme delle previsioni per ciascun ristorante
total_revenues_by_restaurant = {}

for ristorante in ristoranti_da_addestrare:
    # Ottengo il modello e lo scaler dal dizionario
    model_ristorante, scaler_ristorante = modelli_addestrati[ristorante]
    
    # Prendo l'ultima sequenza di dati dal set di test
    last_sequence = X_test_ristorante[-1]
    
    # Genero le previsioni future per il ristorante corrente
    future_predictions = generate_future_predictions(model_ristorante, scaler_ristorante, last_sequence, future_steps)
    
    # Calcolo la somma delle previsioni per il ristorante corrente
    total_revenue = np.sum(future_predictions)
    
    # Memorizzo la somma delle previsioni nel dizionario
    total_revenues_by_restaurant[ristorante] = total_revenue

# Stampo le stime dell'incasso totale per ciascun ristorante
for ristorante, revenue in total_revenues_by_restaurant.items():
    print(f"Stima dell'incasso totale per Ristorante {ristorante} nei prossimi 30 giorni: {revenue:.2f} Euro")
# Out:
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# Stima dell'incasso totale per Ristorante R000 nei prossimi 30 giorni: 677847.94 Euro
# Stima dell'incasso totale per Ristorante R001 nei prossimi 30 giorni: 1053813.12 Euro
# Stima dell'incasso totale per Ristorante R002 nei prossimi 30 giorni: 953230.25 Euro
# Stima dell'incasso totale per Ristorante R003 nei prossimi 30 giorni: 470251.28 Euro
# Stima dell'incasso totale per Ristorante R004 nei prossimi 30 giorni: 889735.88 Euro
# Stima dell'incasso totale per Ristorante R005 nei prossimi 30 giorni: 797097.44 Euro
